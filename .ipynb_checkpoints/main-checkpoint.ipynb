# %%
import json

# %%
# convert .txt files to .dzn that can be used with MiniZinc
def txt_to_dzn(path, sl=None):
    # print(path)
    name = path.split(".")[0]
    with open(path) as f:
        data = json.load(f)
    
    
    alphabet = "{"
    for char in data["alphabet"]:
        alphabet += f"{char},"
    alphabet = alphabet[:-1]
    alphabet += "}"
    alphabet = f"Alphabet = {alphabet};\n"
    # print(alphabet)
    
    num_strings = data["num_strings"]
    ns = f"ns = {num_strings};\n"
    # print(ns)
    
    max_length = max(data["str_length"])
    nc = f"nc = {max_length};\n"
    # print(nc)
    
    sol_length = max_length
    if sl is not None:
        sol_length = sl
        
    sl = f"sl = {sol_length};\n"
    
    neighbours = "[| "
    for s in data["strings"]:
        for i in range(max(max_length, len(s))):
            if i < len(s):
                neighbours += f"I({s[i]}),"
            else:
                neighbours += f"Null,"
        neighbours = neighbours[:-1]
        neighbours += " | "
    neighbours = "neighbours = " + neighbours[:-1] + "];\n"
    # print(neighbours)
    
    with open(f'{name}.dzn', 'w') as f_new:
        f_new.write(alphabet)
        f_new.write(ns)
        f_new.write(nc)
        f_new.write(sl)
        f_new.write(neighbours)

# %%
import os
def all_txt_to_dzn(path_to_instances, sl=None):
    for root, dirs, files in os.walk(path_to_instances):
        for file in files:
            if file.endswith(".txt"):
                path = os.path.join(root, file)
                txt_to_dzn(path, sl=sl)

# %%
import subprocess
import time
import pandas as pd
import os

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
path_to_instances = "C:/Users/basti/Documents/GitHub/PS_in_AI/instances/benchmark"
all_txt_to_dzn(path_to_instances, sl=10)
results1 = test(path_to_instances)
results1.to_csv("benchmark_genetic.csv")

# %%
def test(path_to_instances, timelimit = 5*60*1000, solvers = ["Gecode", "Chuffed"]):

    results = pd.DataFrame(columns=["file", "best", "score", "time", "solver", "max_str_length", "n_str"])
    for solver in solvers:
        # loop over all txt dzn files
        for root, dirs, files in os.walk(path_to_instances):
            for file in sorted(files):
                filename = file.split(".")[0]
                if file.endswith(".dzn"):
                    print(root + "/" +  filename)

                    with open(root + "/" +  filename + ".txt") as f:
                        data = json.load(f)

                    # start MiniZinc as subprocess
                    t0 = time.time()
                    out = subprocess.check_output([
                        "minizinc",
                        "Minimum_editing_distance.mzn",
                        root + "/" +  file, # dzn file as input
                        "--all-solutions", # obtain intermediate solutions
                        "--time-limit", str(timelimit),
                        "--solver", solver,
                        "--random-seed", "0" # reproducibility
                    ])

                    t1 = time.time()

                    # parse and collect results
                    parsed_out = str(out).split("Results: {")[-1].split("}")[0].split(" ") # get last solution
                    best = parsed_out[1]
                    score = int(parsed_out[3])
                    print(f"Found {best} with score {score} in {t1-t0:.2f}s")

                    results = results.append({"file": filename,
                                              "best": best,
                                              "score": score,
                                              "time": t1-t0,
                                              "solver": solver,
                                              "max_str_length": max(data["str_length"]),
                                              "n_str": data["num_strings"]
                                             }, ignore_index=True) 
                    
    return results

# %% [markdown]
# ## Vary string length, leave number of strings constant

# %%
path_to_instances = "benchmark_str_length"
all_txt_to_dzn(path_to_instances, sl=10)
results1 = test(path_to_instances)
results1.to_csv("benchmark_str_length.csv")
# Out:
# benchmark_str_length/p1_10_10-0
# Found AAAAAAACA with score 42 in 1.71s
# benchmark_str_length/p1_10_10-1
# Found AAACACAACA with score 50 in 1.48s
# benchmark_str_length/p1_10_10-2
# Found AAAACAAAAA with score 40 in 0.98s
# benchmark_str_length/p1_10_10-3
# Found ACAAACAAA with score 38 in 0.96s
# benchmark_str_length/p1_10_10-4
# Found CAAAAAAA with score 36 in 1.02s
# benchmark_str_length/p1_10_11-0
# Found ACAAAAAACA with score 44 in 1.05s
# benchmark_str_length/p1_10_11-1
# Found ACAAAAACA with score 46 in 1.16s
# benchmark_str_length/p1_10_11-2
# Found ACAAAACAC with score 54 in 1.60s
# benchmark_str_length/p1_10_11-3
# Found AAAAACAAAA with score 42 in 1.06s
# benchmark_str_length/p1_10_11-4
# Found CAAACAAACA with score 48 in 1.27s
# benchmark_str_length/p1_10_12-0
# Found AACAAACAAA with score 44 in 1.01s
# benchmark_str_length/p1_10_12-1
# Found CAAAAACAAA with score 42 in 0.98s
# benchmark_str_length/p1_10_12-2
# Found AAAAACAAAA with score 42 in 0.97s
# benchmark_str_length/p1_10_12-3
# Found AACAAACAAA with score 40 in 1.00s
# benchmark_str_length/p1_10_12-4
# Found AAAACAAAAA with score 42 in 0.98s
# benchmark_str_length/p1_10_13-0
# Found CCAAAACAAA with score 60 in 1.20s
# benchmark_str_length/p1_10_13-1
# Found AACAAACAAA with score 46 in 1.06s
# benchmark_str_length/p1_10_13-2
# Found AAAAACAACA with score 48 in 1.08s
# benchmark_str_length/p1_10_13-3
# Found AAAAAAACAA with score 48 in 1.02s
# benchmark_str_length/p1_10_13-4
# Found AAAACAAAAC with score 56 in 1.20s
# benchmark_str_length/p1_10_14-0
# Found CAAAAAAAAA with score 46 in 1.07s
# benchmark_str_length/p1_10_14-1
# Found AAAAAAACAA with score 52 in 1.09s
# benchmark_str_length/p1_10_14-2
# Found AAAAAAAAAA with score 54 in 0.98s
# benchmark_str_length/p1_10_14-3
# Found AAAAAACAAA with score 46 in 1.04s
# benchmark_str_length/p1_10_14-4
# Found AAAAAAACAA with score 52 in 1.10s
# benchmark_str_length/p1_10_15-0
# Found AAAAAAAAAA with score 62 in 1.15s
# benchmark_str_length/p1_10_15-1
# Found ACAAAAACAA with score 58 in 1.17s
# benchmark_str_length/p1_10_15-2
# Found AAAAAAAAAA with score 58 in 1.11s
# benchmark_str_length/p1_10_15-3
# Found AAAAAAAAAA with score 54 in 1.09s
# benchmark_str_length/p1_10_15-4
# Found AAAAAAAAAA with score 62 in 1.20s
# benchmark_str_length/p1_10_16-0
# Found AACAAAACAA with score 70 in 1.30s
# benchmark_str_length/p1_10_16-1
# Found AAAAAAAAAA with score 64 in 1.15s
# benchmark_str_length/p1_10_16-2
# Found AAAAAAACAA with score 68 in 1.20s
# benchmark_str_length/p1_10_16-3
# Found AAAAAAAAAA with score 64 in 1.18s
# benchmark_str_length/p1_10_16-4
# Found AAAACAAAAA with score 66 in 1.17s
# benchmark_str_length/p1_10_17-0
# Found AAAAAAAAAC with score 74 in 1.28s
# benchmark_str_length/p1_10_17-1
# Found AAAAAAAAAA with score 72 in 1.24s
# benchmark_str_length/p1_10_17-2
# Found AAAAAAAAAA with score 72 in 1.28s
# benchmark_str_length/p1_10_17-3
# Found AAAAAAAAAA with score 72 in 1.22s
# benchmark_str_length/p1_10_17-4
# Found AAAAAAAAAA with score 70 in 1.21s
# benchmark_str_length/p1_10_3-0
# Found AA with score 16 in 0.27s
# benchmark_str_length/p1_10_3-1
# Found AA with score 16 in 0.26s
# benchmark_str_length/p1_10_3-2
# Found AA with score 10 in 0.22s
# benchmark_str_length/p1_10_3-3
# Found CAA with score 14 in 0.24s
# benchmark_str_length/p1_10_3-4
# Found AA with score 14 in 0.28s
# benchmark_str_length/p1_10_4-0
# Found AACA with score 22 in 0.51s
# benchmark_str_length/p1_10_4-1
# Found AAA with score 18 in 0.43s
# benchmark_str_length/p1_10_4-2
# Found ACACA with score 24 in 0.53s
# benchmark_str_length/p1_10_4-3
# Found AAA with score 16 in 0.43s
# benchmark_str_length/p1_10_4-4
# Found CAACA with score 22 in 0.30s
# benchmark_str_length/p1_10_5-0
# Found ACACAA with score 30 in 0.87s
# benchmark_str_length/p1_10_5-1
# Found ACAAA with score 16 in 0.46s
# benchmark_str_length/p1_10_5-2
# Found ACAAA with score 20 in 0.42s
# benchmark_str_length/p1_10_5-3
# Found AAAAC with score 18 in 0.43s
# benchmark_str_length/p1_10_5-4
# Found AAAA with score 14 in 0.50s
# benchmark_str_length/p1_10_6-0
# Found AAAA with score 24 in 1.15s
# benchmark_str_length/p1_10_6-1
# Found AAAA with score 22 in 0.58s
# benchmark_str_length/p1_10_6-2
# Found ACAAA with score 24 in 0.82s
# benchmark_str_length/p1_10_6-3
# Found AACAA with score 32 in 0.95s
# benchmark_str_length/p1_10_6-4
# Found AAACAAA with score 24 in 0.60s
# benchmark_str_length/p1_10_7-0
# Found AACAAC with score 26 in 0.77s
# benchmark_str_length/p1_10_7-1
# Found AAAACA with score 26 in 0.81s
# benchmark_str_length/p1_10_7-2
# Found AAACAA with score 26 in 0.80s
# benchmark_str_length/p1_10_7-3
# Found CACAACA with score 28 in 0.82s
# benchmark_str_length/p1_10_7-4
# Found AAAAAA with score 22 in 0.81s
# benchmark_str_length/p1_10_8-0
# Found AAAAAA with score 28 in 0.73s
# benchmark_str_length/p1_10_8-1
# Found AAAAA with score 36 in 1.80s
# benchmark_str_length/p1_10_8-2
# Found AACAAAAA with score 22 in 0.72s
# benchmark_str_length/p1_10_8-3
# Found ACAAACAA with score 38 in 1.06s
# benchmark_str_length/p1_10_8-4
# Found AAAAAA with score 30 in 1.03s
# benchmark_str_length/p1_10_9-0
# Found CAACAAAA with score 32 in 0.92s
# benchmark_str_length/p1_10_9-1
# Found AAAACAAA with score 30 in 0.93s
# benchmark_str_length/p1_10_9-2
# Found ACACAAAAA with score 40 in 1.01s
# benchmark_str_length/p1_10_9-3
# Found ACGAACAAA with score 46 in 1.22s
# benchmark_str_length/p1_10_9-4
# Found CAAAACA with score 44 in 1.41s
# benchmark_str_length/p2_10_10-0
# Found AGC with score 30 in 7.49s
# benchmark_str_length/p2_10_10-1
# Found CTA with score 44 in 10.30s
# benchmark_str_length/p2_10_10-2
# Found GATC with score 47 in 18.60s
# benchmark_str_length/p2_10_10-3
# Found CTCG with score 45 in 12.99s
# benchmark_str_length/p2_10_10-4
# Found TCATG with score 44 in 14.59s
# benchmark_str_length/p2_10_11-0
# Found GTCG with score 44 in 9.60s
# benchmark_str_length/p2_10_11-1
# Found GTG with score 45 in 14.65s
# benchmark_str_length/p2_10_11-2
# Found TCA with score 40 in 8.26s
# benchmark_str_length/p2_10_11-3
# Found CTGA with score 38 in 11.92s
# benchmark_str_length/p2_10_11-4
# Found CGTAGG with score 52 in 19.28s
# benchmark_str_length/p2_10_12-0
# Found TGAG with score 45 in 28.08s
# benchmark_str_length/p2_10_12-1
# Found ACTG with score 39 in 6.51s
# benchmark_str_length/p2_10_12-2
# Found TAGA with score 48 in 23.79s
# benchmark_str_length/p2_10_12-3
# Found GAGCTG with score 51 in 9.44s
# benchmark_str_length/p2_10_12-4
# Found TGC with score 50 in 19.31s
# benchmark_str_length/p2_10_13-0
# Found CAGTCA with score 64 in 31.06s
# benchmark_str_length/p2_10_13-1
# Found GACAT with score 51 in 12.02s
# benchmark_str_length/p2_10_13-2
# Found TAGGT with score 58 in 20.66s
# benchmark_str_length/p2_10_13-3
# Found ATC with score 60 in 54.32s
# benchmark_str_length/p2_10_13-4
# Found ATACAT with score 50 in 11.75s
# benchmark_str_length/p2_10_14-0
# Found CATGTTAC with score 77 in 27.87s
# benchmark_str_length/p2_10_14-1
# Found GGCA with score 53 in 18.34s
# benchmark_str_length/p2_10_14-2
# Found GTACTCGT with score 60 in 11.18s
# benchmark_str_length/p2_10_14-3
# Found CCTACG with score 61 in 15.94s
# benchmark_str_length/p2_10_14-4
# Found CTATGC with score 61 in 38.86s
# benchmark_str_length/p2_10_15-0
# Found TCGTGAG with score 65 in 15.49s
# benchmark_str_length/p2_10_15-1
# Found AGGTCC with score 58 in 26.52s
# benchmark_str_length/p2_10_15-2
# Found AGACCACGC with score 69 in 20.05s
# benchmark_str_length/p2_10_15-3
# Found CAGTTC with score 57 in 19.88s
# benchmark_str_length/p2_10_15-4
# Found CTGAG with score 56 in 13.43s
# benchmark_str_length/p2_10_16-0
# Found ACCTGA with score 65 in 18.40s
# benchmark_str_length/p2_10_16-1
# Found TGATAGT with score 63 in 42.57s
# benchmark_str_length/p2_10_16-2
# Found AGCCCTCA with score 76 in 33.34s
# benchmark_str_length/p2_10_16-3
# Found CTGTCAA with score 71 in 22.69s
# benchmark_str_length/p2_10_16-4
# Found GTCCA with score 59 in 26.90s
# benchmark_str_length/p2_10_17-0
# Found CACTCAGGC with score 87 in 60.28s
# benchmark_str_length/p2_10_17-1
# Found TCAGTAT with score 70 in 15.67s
# benchmark_str_length/p2_10_17-2
# Found GTCTAGT with score 61 in 20.69s
# benchmark_str_length/p2_10_17-3
# Found GCCTGA with score 63 in 8.14s
# benchmark_str_length/p2_10_17-4
# Found AGCGTGAT with score 58 in 15.99s
# benchmark_str_length/p2_10_3-0
# Found A with score 15 in 0.37s
# benchmark_str_length/p2_10_3-1
# Found AC with score 14 in 0.29s
# benchmark_str_length/p2_10_3-2
# Found  with score 15 in 0.29s
# benchmark_str_length/p2_10_3-3
# Found  with score 14 in 0.46s
# benchmark_str_length/p2_10_3-4
# Found  with score 14 in 0.31s
# benchmark_str_length/p2_10_4-0
# Found AT with score 20 in 0.88s
# benchmark_str_length/p2_10_4-1
# Found A with score 18 in 0.85s
# benchmark_str_length/p2_10_4-2
# Found GA with score 25 in 1.93s
# benchmark_str_length/p2_10_4-3
# Found A with score 23 in 7.23s
# benchmark_str_length/p2_10_4-4
# Found CG with score 24 in 0.69s
# benchmark_str_length/p2_10_5-0
# Found GAC with score 21 in 0.72s
# benchmark_str_length/p2_10_5-1
# Found GC with score 27 in 1.91s
# benchmark_str_length/p2_10_5-2
# Found A with score 21 in 0.84s
# benchmark_str_length/p2_10_5-3
# Found A with score 18 in 0.39s
# benchmark_str_length/p2_10_5-4
# Found TAC with score 27 in 1.19s
# benchmark_str_length/p2_10_6-0
# Found TC with score 30 in 6.00s
# benchmark_str_length/p2_10_6-1
# Found CTA with score 26 in 0.77s
# benchmark_str_length/p2_10_6-2
# Found TCG with score 33 in 9.66s
# benchmark_str_length/p2_10_6-3
# Found AG with score 26 in 1.01s
# benchmark_str_length/p2_10_6-4
# Found TA with score 31 in 2.15s
# benchmark_str_length/p2_10_7-0
# Found AG with score 26 in 1.05s
# benchmark_str_length/p2_10_7-1
# Found TG with score 30 in 7.34s
# benchmark_str_length/p2_10_7-2
# Found GTC with score 31 in 4.51s
# benchmark_str_length/p2_10_7-3
# Found AC with score 30 in 9.30s
# benchmark_str_length/p2_10_7-4
# Found CATG with score 37 in 5.79s
# benchmark_str_length/p2_10_8-0
# Found AG with score 28 in 2.71s
# benchmark_str_length/p2_10_8-1
# Found C with score 31 in 7.95s
# benchmark_str_length/p2_10_8-2
# Found TG with score 32 in 9.12s
# benchmark_str_length/p2_10_8-3
# Found GT with score 28 in 0.99s
# benchmark_str_length/p2_10_8-4
# Found GA with score 39 in 9.45s
# benchmark_str_length/p2_10_9-0
# Found GTAG with score 37 in 8.24s
# benchmark_str_length/p2_10_9-1
# Found CAA with score 38 in 9.86s
# benchmark_str_length/p2_10_9-2
# Found AGA with score 31 in 2.94s
# benchmark_str_length/p2_10_9-3
# Found TCGT with score 32 in 3.89s
# benchmark_str_length/p2_10_9-4
# Found AGCCTG with score 47 in 5.82s
# benchmark_str_length/p1_10_10-0
# Found AAACAGCCAA with score 62 in 60.22s
# benchmark_str_length/p1_10_10-1
# Found TATAGCACA with score 82 in 60.23s
# benchmark_str_length/p1_10_10-2
# Found AAAAAAA with score 40 in 53.04s
# benchmark_str_length/p1_10_10-3
# Found ACA with score 72 in 60.19s
# benchmark_str_length/p1_10_10-4
# Found CAAAAAAA with score 36 in 44.14s
# benchmark_str_length/p1_10_11-0
# Found ACCGACA with score 78 in 60.23s
# benchmark_str_length/p1_10_11-1
# Found GAAAGGAG with score 96 in 60.30s
# benchmark_str_length/p1_10_11-2
# Found TTTTAAGAAA with score 108 in 60.20s
# benchmark_str_length/p1_10_11-3
# Found CCGCACGCA with score 94 in 60.20s
# benchmark_str_length/p1_10_11-4
# Found GGCAGA with score 100 in 60.26s
# benchmark_str_length/p1_10_12-0
# Found TTTATCCAAG with score 118 in 60.25s
# benchmark_str_length/p1_10_12-1
# Found TGGATAAAAA with score 96 in 60.22s
# benchmark_str_length/p1_10_12-2
# Found CCA with score 98 in 60.24s
# benchmark_str_length/p1_10_12-3
# Found AAAAAC with score 60 in 60.25s
# benchmark_str_length/p1_10_12-4
# Found AAACAACAAA with score 42 in 41.77s
# benchmark_str_length/p1_10_13-0
# Found GACACCAAA with score 88 in 60.24s
# benchmark_str_length/p1_10_13-1
# Found C with score 120 in 60.24s
# benchmark_str_length/p1_10_13-2
# Found A with score 120 in 60.24s
# benchmark_str_length/p1_10_13-3
# Found TCCTCGAAA with score 118 in 60.28s
# benchmark_str_length/p1_10_13-4
# Found GA with score 116 in 60.30s
# benchmark_str_length/p1_10_14-0
# Found ATCC with score 122 in 60.25s
# benchmark_str_length/p1_10_14-1
# Found GA with score 128 in 60.34s
# benchmark_str_length/p1_10_14-2
# Found GCATCAAAAA with score 86 in 60.27s
# benchmark_str_length/p1_10_14-3
# Found  with score 140 in 60.40s
# benchmark_str_length/p1_10_14-4
# Found AA with score 120 in 60.38s
# benchmark_str_length/p1_10_15-0
# Found A with score 140 in 60.36s
# benchmark_str_length/p1_10_15-1
# Found TTCGTCACA with score 136 in 60.35s
# benchmark_str_length/p1_10_15-2
# Found GAGAA with score 128 in 60.28s
# benchmark_str_length/p1_10_15-3
# Found A with score 140 in 60.42s
# benchmark_str_length/p1_10_15-4
# Found  with score 150 in 60.29s
# benchmark_str_length/p1_10_16-0
# Found  with score 160 in 60.30s
# benchmark_str_length/p1_10_16-1
# Found AC with score 140 in 60.33s
# benchmark_str_length/p1_10_16-2
# Found CC with score 144 in 60.30s
# benchmark_str_length/p1_10_16-3
# Found  with score 160 in 60.36s
# benchmark_str_length/p1_10_16-4
# Found  with score 160 in 60.35s
# benchmark_str_length/p1_10_17-0
# Found GA with score 154 in 60.30s
# benchmark_str_length/p1_10_17-1
# Found  with score 170 in 60.30s
# benchmark_str_length/p1_10_17-2
# Found A with score 160 in 60.30s
# benchmark_str_length/p1_10_17-3
# Found CG with score 160 in 60.32s
# benchmark_str_length/p1_10_17-4
# Found C with score 160 in 60.29s
# benchmark_str_length/p1_10_3-0
# Found AA with score 16 in 0.47s
# benchmark_str_length/p1_10_3-1
# Found AA with score 16 in 0.42s
# benchmark_str_length/p1_10_3-2
# Found AA with score 10 in 0.28s
# benchmark_str_length/p1_10_3-3
# Found AA with score 14 in 0.39s
# benchmark_str_length/p1_10_3-4
# Found AA with score 14 in 0.35s
# benchmark_str_length/p1_10_4-0
# Found AACA with score 22 in 1.13s
# benchmark_str_length/p1_10_4-1
# Found AAA with score 18 in 0.86s
# benchmark_str_length/p1_10_4-2
# Found AA with score 24 in 1.52s
# benchmark_str_length/p1_10_4-3
# Found AAA with score 16 in 0.82s
# benchmark_str_length/p1_10_4-4
# Found CAACA with score 22 in 0.64s
# benchmark_str_length/p1_10_5-0
# Found CAA with score 30 in 4.28s
# benchmark_str_length/p1_10_5-1
# Found ACAAA with score 16 in 1.79s
# benchmark_str_length/p1_10_5-2
# Found CAAA with score 20 in 1.74s
# benchmark_str_length/p1_10_5-3
# Found AAAA with score 18 in 1.02s
# benchmark_str_length/p1_10_5-4
# Found AAAA with score 14 in 1.15s
# benchmark_str_length/p1_10_6-0
# Found AAAA with score 24 in 11.17s
# benchmark_str_length/p1_10_6-1
# Found AAAA with score 22 in 4.27s
# benchmark_str_length/p1_10_6-2
# Found ACAAA with score 24 in 3.37s
# benchmark_str_length/p1_10_6-3
# Found AACAA with score 32 in 12.83s
# benchmark_str_length/p1_10_6-4
# Found AAAAA with score 24 in 2.64s
# benchmark_str_length/p1_10_7-0
# Found AACAAC with score 26 in 24.42s
# benchmark_str_length/p1_10_7-1
# Found AAAACA with score 26 in 12.73s
# benchmark_str_length/p1_10_7-2
# Found AAACAA with score 26 in 28.61s
# benchmark_str_length/p1_10_7-3
# Found CACAACA with score 28 in 17.97s
# benchmark_str_length/p1_10_7-4
# Found AAAAA with score 22 in 17.42s
# benchmark_str_length/p1_10_8-0
# Found AAAAAA with score 28 in 38.45s
# benchmark_str_length/p1_10_8-1
# Found AAAAA with score 36 in 38.68s
# benchmark_str_length/p1_10_8-2
# Found AACAAAAA with score 22 in 29.24s
# benchmark_str_length/p1_10_8-3
# Found GGAAA with score 62 in 60.18s
# benchmark_str_length/p1_10_8-4
# Found AAAAAA with score 30 in 40.39s
# benchmark_str_length/p1_10_9-0
# Found GACAAAA with score 38 in 60.24s
# benchmark_str_length/p1_10_9-1
# Found GAAGGAAAG with score 68 in 60.22s
# benchmark_str_length/p1_10_9-2
# Found ACCACAA with score 54 in 60.29s
# benchmark_str_length/p1_10_9-3
# Found AAAAAC with score 46 in 56.81s
# benchmark_str_length/p1_10_9-4
# Found CCAGAAAA with score 56 in 60.17s
# benchmark_str_length/p2_10_10-0
# Found AGC with score 30 in 2.04s
# benchmark_str_length/p2_10_10-1
# Found TC with score 44 in 3.17s
# benchmark_str_length/p2_10_10-2
# Found GAT with score 47 in 11.63s
# benchmark_str_length/p2_10_10-3
# Found CTG with score 45 in 8.50s
# benchmark_str_length/p2_10_10-4
# Found CAT with score 44 in 36.86s
# benchmark_str_length/p2_10_11-0
# Found GTCG with score 44 in 5.25s
# benchmark_str_length/p2_10_11-1
# Found GTG with score 45 in 8.24s
# benchmark_str_length/p2_10_11-2
# Found TCA with score 40 in 5.36s
# benchmark_str_length/p2_10_11-3
# Found CTGA with score 38 in 4.49s
# benchmark_str_length/p2_10_11-4
# Found CGTAG with score 52 in 21.09s
# benchmark_str_length/p2_10_12-0
# Found TGAG with score 45 in 6.82s
# benchmark_str_length/p2_10_12-1
# Found ACTG with score 39 in 3.12s
# benchmark_str_length/p2_10_12-2
# Found TAGA with score 48 in 42.00s
# benchmark_str_length/p2_10_12-3
# Found GAGCT with score 51 in 23.78s
# benchmark_str_length/p2_10_12-4
# Found TGC with score 50 in 7.73s
# benchmark_str_length/p2_10_13-0
# Found GCGTA with score 68 in 60.22s
# benchmark_str_length/p2_10_13-1
# Found GACAT with score 51 in 13.01s
# benchmark_str_length/p2_10_13-2
# Found ATGGT with score 58 in 16.14s
# benchmark_str_length/p2_10_13-3
# Found AGT with score 60 in 17.14s
# benchmark_str_length/p2_10_13-4
# Found AACAT with score 50 in 14.62s
# benchmark_str_length/p2_10_14-0
# Found TTGA with score 81 in 60.20s
# benchmark_str_length/p2_10_14-1
# Found GGCA with score 53 in 18.22s
# benchmark_str_length/p2_10_14-2
# Found CGTCGT with score 60 in 60.30s
# benchmark_str_length/p2_10_14-3
# Found CCTAG with score 61 in 57.13s
# benchmark_str_length/p2_10_14-4
# Found CGC with score 63 in 60.17s
# benchmark_str_length/p2_10_15-0
# Found TCTG with score 67 in 60.18s
# benchmark_str_length/p2_10_15-1
# Found ATGC with score 58 in 39.50s
# benchmark_str_length/p2_10_15-2
# Found GTCTCAACC with score 77 in 60.29s
# benchmark_str_length/p2_10_15-3
# Found TTC with score 57 in 39.87s
# benchmark_str_length/p2_10_15-4
# Found CTGAG with score 56 in 54.96s
# benchmark_str_length/p2_10_16-0
# Found CAGA with score 69 in 60.18s
# benchmark_str_length/p2_10_16-1
# Found ATAGT with score 63 in 60.16s
# benchmark_str_length/p2_10_16-2
# Found GCTACCCG with score 84 in 60.20s
# benchmark_str_length/p2_10_16-3
# Found ACTGTC with score 75 in 60.31s
# benchmark_str_length/p2_10_16-4
# Found GTCA with score 59 in 57.09s
# benchmark_str_length/p2_10_17-0
# Found CTAG with score 91 in 60.21s
# benchmark_str_length/p2_10_17-1
# Found TTAG with score 74 in 60.28s
# benchmark_str_length/p2_10_17-2
# Found GTAGTG with score 65 in 60.22s
# benchmark_str_length/p2_10_17-3
# Found CCTGA with score 63 in 49.17s
# benchmark_str_length/p2_10_17-4
# Found CGTGA with score 62 in 60.17s
# benchmark_str_length/p2_10_3-0
# Found A with score 15 in 0.51s
# benchmark_str_length/p2_10_3-1
# Found AC with score 14 in 0.30s
# benchmark_str_length/p2_10_3-2
# Found  with score 15 in 0.34s
# benchmark_str_length/p2_10_3-3
# Found  with score 14 in 0.29s
# benchmark_str_length/p2_10_3-4
# Found  with score 14 in 0.26s
# benchmark_str_length/p2_10_4-0
# Found AT with score 20 in 0.50s
# benchmark_str_length/p2_10_4-1
# Found A with score 18 in 0.41s
# benchmark_str_length/p2_10_4-2
# Found GA with score 25 in 0.65s
# benchmark_str_length/p2_10_4-3
# Found  with score 23 in 0.45s
# benchmark_str_length/p2_10_4-4
# Found CG with score 24 in 0.58s
# benchmark_str_length/p2_10_5-0
# Found C with score 21 in 0.71s
# benchmark_str_length/p2_10_5-1
# Found GC with score 27 in 0.78s
# benchmark_str_length/p2_10_5-2
# Found A with score 21 in 0.44s
# benchmark_str_length/p2_10_5-3
# Found A with score 18 in 0.38s
# benchmark_str_length/p2_10_5-4
# Found AT with score 27 in 0.75s
# benchmark_str_length/p2_10_6-0
# Found T with score 30 in 1.04s
# benchmark_str_length/p2_10_6-1
# Found  with score 26 in 0.54s
# benchmark_str_length/p2_10_6-2
# Found CT with score 33 in 1.13s
# benchmark_str_length/p2_10_6-3
# Found A with score 26 in 0.66s
# benchmark_str_length/p2_10_6-4
# Found TA with score 31 in 1.95s
# benchmark_str_length/p2_10_7-0
# Found AG with score 26 in 0.78s
# benchmark_str_length/p2_10_7-1
# Found TG with score 30 in 0.94s
# benchmark_str_length/p2_10_7-2
# Found TC with score 31 in 0.87s
# benchmark_str_length/p2_10_7-3
# Found AC with score 30 in 1.82s
# benchmark_str_length/p2_10_7-4
# Found AT with score 37 in 2.40s
# benchmark_str_length/p2_10_8-0
# Found AG with score 28 in 1.20s
# benchmark_str_length/p2_10_8-1
# Found C with score 31 in 1.06s
# benchmark_str_length/p2_10_8-2
# Found CT with score 32 in 0.94s
# benchmark_str_length/p2_10_8-3
# Found GT with score 28 in 0.96s
# benchmark_str_length/p2_10_8-4
# Found GA with score 39 in 1.29s
# benchmark_str_length/p2_10_9-0
# Found GT with score 37 in 6.25s
# benchmark_str_length/p2_10_9-1
# Found CAA with score 38 in 2.34s
# benchmark_str_length/p2_10_9-2
# Found AG with score 31 in 1.81s
# benchmark_str_length/p2_10_9-3
# Found CGT with score 32 in 0.85s
# benchmark_str_length/p2_10_9-4
# Found CCTG with score 47 in 7.15s

# %%
results1
# Out:
#            file        best score      time   solver max_str_length n_str
# 0    p1_10_10-0   AAAAAAACA    42  1.712484   Gecode             10    10
# 1    p1_10_10-1  AAACACAACA    50  1.478932   Gecode             10    10
# 2    p1_10_10-2  AAAACAAAAA    40  0.977641   Gecode             10    10
# 3    p1_10_10-3   ACAAACAAA    38  0.959318   Gecode             10    10
# 4    p1_10_10-4    CAAAAAAA    36  1.018450   Gecode             10    10
# ..          ...         ...   ...       ...      ...            ...   ...
# 295   p2_10_9-0          GT    37  6.250572  Chuffed              7    10
# 296   p2_10_9-1         CAA    38  2.343952  Chuffed              9    10
# 297   p2_10_9-2          AG    31  1.812681  Chuffed              8    10
# 298   p2_10_9-3         CGT    32  0.851414  Chuffed              8    10
# 299   p2_10_9-4        CCTG    47  7.153045  Chuffed              9    10
#
# [300 rows x 7 columns]

# %%
p1 = results1[results1.file.str.contains("p1")]

gc = p1[p1.solver == "Gecode"].groupby("max_str_length").mean()
ch = p1[p1.solver == "Chuffed"].groupby("max_str_length").mean()

plt.plot(gc, label="Gecode")
plt.plot(ch, label="Chuffed")
plt.suptitle("Same string length")
plt.xlabel("max string length")
plt.ylabel("time (s)")
plt.yscale("log")
plt.legend()
plt.savefig("str_length_p1.pdf")

# %%
p2 = results1[results1.file.str.contains("p2")]

gc = p2[p2.solver == "Gecode"].groupby("max_str_length").mean()
ch = p2[p2.solver == "Chuffed"].groupby("max_str_length").mean()

plt.plot(gc, label="Gecode")
plt.plot(ch, label="Chuffed")
plt.suptitle("Mixed string length")
plt.xlabel("max string length")
plt.ylabel("time (s)")
plt.yscale("log")
plt.legend()
plt.savefig("str_length_p2.pdf")

# %% [markdown]
# ## Vary numer of strings, leave string length constant

# %%
path_to_instances = "benchmark_num_str"
all_txt_to_dzn(path_to_instances, sl=10)
results2 = test(path_to_instances)
results2.to_csv("benchmark_num_str.csv")
# Out:
# benchmark_num_str/p1_10_10-0
# Found ACAACAACA with score 44 in 1.40s
# benchmark_num_str/p1_10_10-1
# Found AACAAACAA with score 36 in 1.05s
# benchmark_num_str/p1_10_10-2
# Found AAAACACAAA with score 42 in 1.01s
# benchmark_num_str/p1_10_10-3
# Found AAAACAACA with score 42 in 1.08s
# benchmark_num_str/p1_10_10-4
# Found ACAAAACAA with score 36 in 0.89s
# benchmark_num_str/p1_1_10-0
# Found AACCCAAAAG with score 0 in 0.13s
# benchmark_num_str/p1_1_10-1
# Found GAACACCAAA with score 0 in 0.15s
# benchmark_num_str/p1_1_10-2
# Found ACACAACAAA with score 0 in 0.15s
# benchmark_num_str/p1_1_10-3
# Found CCAAACACAG with score 0 in 0.16s
# benchmark_num_str/p1_1_10-4
# Found AAAAACCGAA with score 0 in 0.15s
# benchmark_num_str/p1_2_10-0
# Found ACAACCAAAA with score 6 in 0.23s
# benchmark_num_str/p1_2_10-1
# Found AAACAAAAAA with score 8 in 0.36s
# benchmark_num_str/p1_2_10-2
# Found CACAACAACA with score 4 in 0.32s
# benchmark_num_str/p1_2_10-3
# Found CAAACAAAAA with score 6 in 0.23s
# benchmark_num_str/p1_2_10-4
# Found AAAACAACCA with score 4 in 0.24s
# benchmark_num_str/p1_3_10-0
# Found ACAAAACC with score 10 in 0.39s
# benchmark_num_str/p1_3_10-1
# Found ACAACAAAAA with score 8 in 0.35s
# benchmark_num_str/p1_3_10-2
# Found CACAAACCA with score 7 in 0.33s
# benchmark_num_str/p1_3_10-3
# Found CAAAAAACA with score 9 in 0.34s
# benchmark_num_str/p1_3_10-4
# Found AAACACAAA with score 7 in 0.44s
# benchmark_num_str/p1_4_10-0
# Found AAAACACAAA with score 20 in 0.64s
# benchmark_num_str/p1_4_10-1
# Found AAAAACAAAA with score 16 in 0.42s
# benchmark_num_str/p1_4_10-2
# Found CAAACAAAAA with score 12 in 0.41s
# benchmark_num_str/p1_4_10-3
# Found AACCAAACAA with score 12 in 0.56s
# benchmark_num_str/p1_4_10-4
# Found AAAAAAAAAA with score 8 in 0.46s
# benchmark_num_str/p1_5_10-0
# Found ACAAACCAA with score 17 in 0.52s
# benchmark_num_str/p1_5_10-1
# Found AACAAAAAA with score 15 in 0.48s
# benchmark_num_str/p1_5_10-2
# Found AGAAAAACA with score 19 in 0.62s
# benchmark_num_str/p1_5_10-3
# Found AACACACAAA with score 22 in 0.65s
# benchmark_num_str/p1_5_10-4
# Found ACACAACAAA with score 18 in 0.54s
# benchmark_num_str/p1_6_10-0
# Found ACAAACCAAA with score 28 in 0.67s
# benchmark_num_str/p1_6_10-1
# Found ACAAACAA with score 24 in 0.78s
# benchmark_num_str/p1_6_10-2
# Found CACAAAAACA with score 18 in 0.56s
# benchmark_num_str/p1_6_10-3
# Found AACAAAA with score 24 in 1.02s
# benchmark_num_str/p1_6_10-4
# Found ACAACAAAAA with score 22 in 0.76s
# benchmark_num_str/p1_7_10-0
# Found ACAAAAAC with score 22 in 0.79s
# benchmark_num_str/p1_7_10-1
# Found AACAAACA with score 28 in 0.77s
# benchmark_num_str/p1_7_10-2
# Found ACAAAAAAA with score 31 in 0.90s
# benchmark_num_str/p1_7_10-3
# Found AAAAAACAAC with score 16 in 0.61s
# benchmark_num_str/p1_7_10-4
# Found ACAACCAAAA with score 28 in 0.77s
# benchmark_num_str/p1_8_10-0
# Found ACAAACAAAA with score 28 in 0.78s
# benchmark_num_str/p1_8_10-1
# Found AAACACAAAA with score 38 in 0.89s
# benchmark_num_str/p1_8_10-2
# Found ACAACAACAA with score 30 in 0.79s
# benchmark_num_str/p1_8_10-3
# Found AACCACAACA with score 30 in 0.80s
# benchmark_num_str/p1_8_10-4
# Found AAACAAAA with score 28 in 0.76s
# benchmark_num_str/p1_9_10-0
# Found AACAAAAA with score 32 in 0.84s
# benchmark_num_str/p1_9_10-1
# Found CAAAAAAA with score 44 in 0.96s
# benchmark_num_str/p1_9_10-2
# Found AACAAAAA with score 36 in 1.12s
# benchmark_num_str/p1_9_10-3
# Found AAAAAAACA with score 29 in 0.83s
# benchmark_num_str/p1_9_10-4
# Found ACAAACAAAA with score 32 in 0.88s
# benchmark_num_str/p1_10_10-0
# Found CAAC with score 64 in 60.18s
# benchmark_num_str/p1_10_10-1
# Found AG with score 92 in 60.23s
# benchmark_num_str/p1_10_10-2
# Found CC with score 86 in 60.19s
# benchmark_num_str/p1_10_10-3
# Found AAAACAAA with score 42 in 57.41s
# benchmark_num_str/p1_10_10-4
# Found AAAAACAA with score 36 in 29.24s
# benchmark_num_str/p1_1_10-0
# Found AACCCAAAAG with score 0 in 0.21s
# benchmark_num_str/p1_1_10-1
# Found GAACACCAAA with score 0 in 0.25s
# benchmark_num_str/p1_1_10-2
# Found ACACAACAAA with score 0 in 0.24s
# benchmark_num_str/p1_1_10-3
# Found CCAAACACAG with score 0 in 0.24s
# benchmark_num_str/p1_1_10-4
# Found AAAAACCGAA with score 0 in 0.24s
# benchmark_num_str/p1_2_10-0
# Found ACAAAAGA with score 6 in 0.43s
# benchmark_num_str/p1_2_10-1
# Found AAAAAA with score 8 in 0.42s
# benchmark_num_str/p1_2_10-2
# Found CAACAACCAC with score 4 in 0.47s
# benchmark_num_str/p1_2_10-3
# Found CAGAACCAA with score 6 in 0.44s
# benchmark_num_str/p1_2_10-4
# Found ACAAACACCG with score 4 in 0.80s
# benchmark_num_str/p1_3_10-0
# Found ACAAAACC with score 10 in 0.78s
# benchmark_num_str/p1_3_10-1
# Found ACAACAAAAA with score 8 in 0.97s
# benchmark_num_str/p1_3_10-2
# Found CACAAACCA with score 7 in 0.86s
# benchmark_num_str/p1_3_10-3
# Found CAAAAAACA with score 9 in 0.95s
# benchmark_num_str/p1_3_10-4
# Found AAACACAAA with score 7 in 1.21s
# benchmark_num_str/p1_4_10-0
# Found AAACAA with score 20 in 1.77s
# benchmark_num_str/p1_4_10-1
# Found AAAAACAAA with score 16 in 2.19s
# benchmark_num_str/p1_4_10-2
# Found CAAACAAGAA with score 12 in 3.04s
# benchmark_num_str/p1_4_10-3
# Found AAAAAAA with score 12 in 1.51s
# benchmark_num_str/p1_4_10-4
# Found AAAAAAAAAA with score 8 in 1.29s
# benchmark_num_str/p1_5_10-0
# Found ACAAACCAA with score 17 in 8.39s
# benchmark_num_str/p1_5_10-1
# Found AACAAAAAA with score 15 in 3.58s
# benchmark_num_str/p1_5_10-2
# Found AGAAAAACA with score 19 in 2.95s
# benchmark_num_str/p1_5_10-3
# Found AACACAAA with score 22 in 6.37s
# benchmark_num_str/p1_5_10-4
# Found ACAACAAA with score 18 in 4.11s
# benchmark_num_str/p1_6_10-0
# Found ACAAACCA with score 28 in 16.30s
# benchmark_num_str/p1_6_10-1
# Found ACAAACAA with score 24 in 9.78s
# benchmark_num_str/p1_6_10-2
# Found CACAAAAACA with score 18 in 4.62s
# benchmark_num_str/p1_6_10-3
# Found AACAAAA with score 24 in 8.12s
# benchmark_num_str/p1_6_10-4
# Found ACAAACAAAA with score 22 in 6.04s
# benchmark_num_str/p1_7_10-0
# Found ACAAAAAC with score 22 in 11.96s
# benchmark_num_str/p1_7_10-1
# Found AACAAACA with score 28 in 9.51s
# benchmark_num_str/p1_7_10-2
# Found CAAAAAACA with score 31 in 30.58s
# benchmark_num_str/p1_7_10-3
# Found AAAAAACAAC with score 16 in 6.10s
# benchmark_num_str/p1_7_10-4
# Found ACAACACAAA with score 28 in 19.18s
# benchmark_num_str/p1_8_10-0
# Found ACAAAAAA with score 28 in 41.19s
# benchmark_num_str/p1_8_10-1
# Found AAACAAA with score 38 in 36.34s
# benchmark_num_str/p1_8_10-2
# Found ACAACAAAA with score 30 in 48.39s
# benchmark_num_str/p1_8_10-3
# Found AACCACAACA with score 30 in 17.09s
# benchmark_num_str/p1_8_10-4
# Found AAAAAAA with score 28 in 18.20s
# benchmark_num_str/p1_9_10-0
# Found AACC with score 60 in 60.20s
# benchmark_num_str/p1_9_10-1
# Found CAAAAAAA with score 44 in 33.84s
# benchmark_num_str/p1_9_10-2
# Found AACAAAAA with score 36 in 37.18s
# benchmark_num_str/p1_9_10-3
# Found AAACAAAAC with score 29 in 34.93s
# benchmark_num_str/p1_9_10-4
# Found ACAAACAAAA with score 32 in 52.90s

# %%
p1 = results2[results2.file.str.contains("p1")]

gc = p1[p1.solver == "Gecode"].groupby("n_str").mean()
ch = p1[p1.solver == "Chuffed"].groupby("n_str").mean()

plt.plot(gc, label="Gecode")
plt.plot(ch, label="Chuffed")
plt.suptitle("Same string length")
plt.xlabel("Numer of strings")
plt.ylabel("time (s)")
plt.yscale("log")
plt.legend()
plt.savefig("num_str.pdf")

# %% [markdown]
# ## Investigate effect of solution length

# %%
# solve minimize global_edit_distance;

problem = "instances/p2/p2_15_20-0"
results3 = pd.DataFrame(columns=["sol_length", "best", "score", "time"])
for sol_length in range(1,21):
    txt_to_dzn(problem + ".txt", sl=sol_length)
    timelimit = 60*1000

    t0 = time.time()
    out = subprocess.check_output([
                            "minizinc",
                            "Minimum_editing_distance.mzn",
                            problem + ".dzn",
                            "--all-solutions",
                            "--time-limit", str(timelimit),
                            "--solver", "Gecode",
                            "--random-seed", "0"
                        ])

    t1 = time.time()
    parsed_out = str(out).split("Results: {")[-1].split("}")[0].split(" ") # get last solution
    best = parsed_out[1]
    score = int(parsed_out[3])
    print(f"Solution length: {sol_length}. Found {best} with score {score} in {t1-t0:.2f}s")
    results3 = results3.append({"sol_length": sol_length, "best": best, "score": score, "time":t1-t0},
                             ignore_index=True)
# Out:
# Solution length: 1. Found A with score 184 in 0.47s
# Solution length: 2. Found CA with score 169 in 0.39s
# Solution length: 3. Found CGA with score 156 in 0.54s
# Solution length: 4. Found CCGA with score 147 in 0.70s
# Solution length: 5. Found CTGGA with score 142 in 0.98s
# Solution length: 6. Found CTCGGA with score 141 in 1.81s
# Solution length: 7. Found CTCGATG with score 138 in 4.19s
# Solution length: 8. Found ACTCGATG with score 137 in 11.39s
# Solution length: 9. Found ACTCGATG with score 137 in 36.59s
# Solution length: 10. Found GATCTCGGAC with score 139 in 60.39s
# Solution length: 11. Found GATCTCGGACA with score 144 in 60.44s
# Solution length: 12. Found GACTCATGGCAA with score 153 in 60.48s
# Solution length: 13. Found GACTCATGGCAAA with score 162 in 60.51s
# Solution length: 14. Found GACTACGTCCAAAA with score 175 in 60.53s
# Solution length: 15. Found ACTCATGGACAAAAA with score 190 in 60.59s
# Solution length: 16. Found ACTCATGGACAAAAAA with score 205 in 60.61s
# Solution length: 17. Found ACTCATGGACAAAAAAA with score 218 in 60.65s
# Solution length: 18. Found GACCTCGGCAAAAAAAAA with score 239 in 60.71s
# Solution length: 19. Found GACCTCGGCAAAAAAAAAA with score 254 in 60.76s
# Solution length: 20. Found GACCTCGGCAAAAAAAAAAA with score 269 in 60.82s

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel("Max solution length")
ax1.set_ylabel("score", color=color)
ax1.plot(results3.sol_length, results3.score, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(100, 300)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel("time (s)", color=color)
ax2.plot(results3.sol_length, results3.time, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Default")
plt.savefig("score_vs_time.pdf")

# %%
# ann: random = int_search(solution, dom_w_deg, indomain_random, complete);
# solve::random minimize global_edit_distance;

problem = "instances/p2/p2_15_20-0"
results4 = pd.DataFrame(columns=["sol_length", "best", "score", "time"])
for sol_length in range(1,21):
    txt_to_dzn(problem + ".txt", sl=sol_length)
    timelimit = 60*1000

    t0 = time.time()
    out = subprocess.check_output([
                            "minizinc",
                            "Minimum_editing_distance.mzn",
                            problem + ".dzn",
                            "--all-solutions",
                            "--time-limit", str(timelimit),
                            "--solver", "Gecode",
                            "--random-seed", "0",
                            "--restart", "luby", # random restart parameters
                            "--restart-scale", "600"
                        ])

    t1 = time.time()
    parsed_out = str(out).split("Results: {")[-1].split("}")[0].split(" ") # get last solution
    best = parsed_out[1]
    score = int(parsed_out[3])
    print(f"Solution length: {sol_length}. Found {best} with score {score} in {t1-t0:.2f}s")
    results4 = results4.append({"sol_length": sol_length, "best": best, "score": score, "time":t1-t0},
                             ignore_index=True)
# Out:
# Solution length: 1. Found G with score 184 in 0.31s
# Solution length: 2. Found CA with score 169 in 0.41s
# Solution length: 3. Found CGA with score 156 in 0.57s
# Solution length: 4. Found CTGA with score 147 in 0.80s
# Solution length: 5. Found CTGGA with score 142 in 1.29s
# Solution length: 6. Found CCGATG with score 141 in 2.84s
# Solution length: 7. Found CTCGATG with score 138 in 16.23s
# Solution length: 8. Found ACTCGATG with score 137 in 41.06s
# Solution length: 9. Found ACTCGATG with score 137 in 60.36s
# Solution length: 10. Found CTCGCATG with score 139 in 60.46s
# Solution length: 11. Found ACTCGATG with score 137 in 60.46s
# Solution length: 12. Found CGACTGCAG with score 140 in 60.52s
# Solution length: 13. Found CTCGA with score 144 in 60.52s
# Solution length: 14. Found CACTGACG with score 141 in 60.60s
# Solution length: 15. Found CTCTGACAG with score 146 in 60.62s
# Solution length: 16. Found ATGGCA with score 149 in 60.69s
# Solution length: 17. Found GTCCTGGAC with score 146 in 60.65s
# Solution length: 18. Found ACTCTGAG with score 143 in 60.74s
# Solution length: 19. Found CGGAAC with score 147 in 60.77s
# Solution length: 20. Found CTGATC with score 147 in 60.83s

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel("Max solution length")
ax1.set_ylabel("score", color=color)
ax1.plot(results4.sol_length, results4.score, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(100, 300)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel("time (s)", color=color)
ax2.plot(results4.sol_length, results4.time, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Random restarts")
plt.savefig("score_vs_time_random.pdf")

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel("Max solution length")
ax1.set_ylabel("score", color=color)
ax1.plot(results3.sol_length, results3.score, linestyle="--", color=color, label="Default")
ax1.plot(results4.sol_length, results4.score, color=color, label="Random Restart")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(100, 300)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel("time (s)", color=color)
ax2.plot(results3.sol_length, results3.time, linestyle="--", color=color)
ax2.plot(results4.sol_length, results4.time, color=color)
ax2.tick_params(axis='y', labelcolor=color)

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="black", linestyle="--"),
                Line2D([0], [0], color="black")]
plt.legend(custom_lines, ["Default", "Random Restart"])
plt.savefig("score_vs_time_compare.pdf")
